# %% [markdown]
# # Introduction
# The Nominatim API is a REST API (provided by OpenStreetMap), that returns geographic coordinates (latitude and longitude) from a postal address. If several postal addresses (due to inaccuracy or non-existent street number) corresponding to the request are found, the API returns several coordinates, each time with an `importance` score. The coordinates are given in descending order of importance, so you can select only the first address.

# %%
# Execute the code below :

import requests
link = "https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,Catania,Italy&format=json"
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:91.0) Gecko/20100101 Firefox/91.0',
    'Referer': 'https://www.example.com'
}
r = requests.get(link, headers=headers).json()
r
# Out:
# [{'place_id': 54159761,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 1125079468,
#   'lat': '37.2251967',
#   'lon': '14.5246856',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.05339371862363619,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Le Sfere, Caltagirone, Catania, Sicilia, 95041, Italia',
#   'boundingbox': ['37.2250444', '37.2253490', '14.5244318', '14.5249395']},
#  {'place_id': 53625145,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 58232256,
#   'lat': '37.6091345',
#   'lon': '15.1596728',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.0533936133363851,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Sciarelle, Acireale, Catania, Sicilia, 95024, Italia',
#   'boundingbox': ['37.6088571', '37.6091358', '15.1591549', '15.1602847']},
#  {'place_id': 57788919,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 128394486,
#   'lat': '37.6090499',
#   'lon': '15.1606580',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.0533936133363851,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Santa Caterina, Acireale, Catania, Sicilia, 95024, Italia',
#   'boundingbox': ['37.6089805', '37.6091110', '15.1602847', '15.1610300']},
#  {'place_id': 54121398,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 167016177,
#   'lat': '37.5676168',
#   'lon': '14.9106913',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.05339132753490498,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Santa Marina, Paternò, Catania, Sicilia, 95047, Italia',
#   'boundingbox': ['37.5673863', '37.5680619', '14.9106500', '14.9109837']},
#  {'place_id': 53737449,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 1203329854,
#   'lat': '37.7242484',
#   'lon': '15.1789902',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.053390183108262726,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Tagliaborsa, San Giovanni Montebello, Giarre, Catania, Sicilia, 95014, Italia',
#   'boundingbox': ['37.7234970', '37.7249937', '15.1784912', '15.1794786']},
#  {'place_id': 54060742,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 540088607,
#   'lat': '37.7871875',
#   'lon': '14.8356602',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.053390039673456895,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Bronte, Catania, Sicilia, 95034, Italia',
#   'boundingbox': ['37.7871116', '37.7872091', '14.8351854', '14.8361387']},
#  {'place_id': 54181538,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 340599607,
#   'lat': '37.2133425',
#   'lon': '14.6341732',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.053389035629816096,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Grammichele, Catania, Sicilia, 95042, Italia',
#   'boundingbox': ['37.2132636', '37.2135294', '14.6341245', '14.6343514']},
#  {'place_id': 57843981,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 409895581,
#   'lat': '37.5111836',
#   'lon': '15.0949140',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.05340454642557409,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Picanello-Ognina-Barriera-Canalicchio, Catania, Sicilia, 95131, Italia',
#   'boundingbox': ['37.5111306', '37.5112366', '15.0948817', '15.0949463']},
#  {'place_id': 54133210,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 211056073,
#   'lat': '37.5563508',
#   'lon': '14.9172646',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.05339132753490498,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Astrel, Giaconia, Belpasso, Catania, Sicilia, 95032, Italia',
#   'boundingbox': ['37.5559895', '37.5567121', '14.9169673', '14.9175618']},
#  {'place_id': 54104775,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 1312331717,
#   'lat': '37.6666778',
#   'lon': '14.8355145',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.053390367742427676,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Adrano, Catania, Sicilia, 95031, Italia',
#   'boundingbox': ['37.6665771', '37.6667784', '14.8352642', '14.8357647']}]

# %%
# Here we select only the first address (index 0)
print("First address :", r[0])
print("First address longitude :",r[0]['lon'])
print("First address latitude :",r[0]['lat'])
# Out:
# First address : {'place_id': 54159761, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 1125079468, 'lat': '37.2251967', 'lon': '14.5246856', 'class': 'highway', 'type': 'residential', 'place_rank': 26, 'importance': 0.05339371862363619, 'addresstype': 'road', 'name': 'Via Pietro Mascagni', 'display_name': 'Via Pietro Mascagni, Le Sfere, Caltagirone, Catania, Sicilia, 95041, Italia', 'boundingbox': ['37.2250444', '37.2253490', '14.5244318', '14.5249395']}
# First address longitude : 14.5246856
# First address latitude : 37.2251967

# %%
# For ease of use, you can add a limit on the number of items returned:

link = "https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,Catania,Italy&format=json"
r = requests.get(link, headers=headers).json()
print("WITHOUT limit, how many coordinates does this address return?",len(r))

link = "https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,Catania,Italy&format=json&limit=1"
r = requests.get(link, headers=headers).json()
print("WITH limit, how many coordinates does this address return?",len(r))
# Out:
# WITHOUT limit, how many coordinates does this address return? 10
# WITH limit, how many coordinates does this address return? 1

# %% [markdown]
# ## How to create your API query
# It's up to you to modify the string to create the right request URL

# %%
# We observe that the query consists of a fixed part, followed by the address to be searched for.
# An URL cannot contain a " " space character,
# and special characters or accents should be avoided if possible

link_main = 'https://nominatim.openstreetmap.org/?q='
address = '54 Via Pietro Mascagni, Catania, Italy'
link_end = '&format=json&limit=1'

link = link_main + address.replace(",", "").replace(" ","+")# It's your turn here. Your goal is to get a link in the right format

print(link + link_end)
# Out:
# https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni+Catania+Italy&format=json&limit=1

# %%
# Create a function here that turns a postal address into a request URL for the Nominatim API,
# then makes the request and returns the coordinates :
def API_address(postal_address):
    link_main = 'https://nominatim.openstreetmap.org/?q='
    link_end = '&format=json&limit=1'
    link = link_main + postal_address.replace(",", "").replace(" ","+") + link_end
    req = requests.get(link, headers=headers).json()
    resp = [req[0]['lon'], req [0]['lat']]
    return resp[::-1]

# %%
# Test it here:
API_address("Via Porta di Ferro, 47, 95131 Catania CT")
# Out:
# ['37.5020931', '15.0931951']

# %% [markdown]
# # DataViz
# Latitude & Longitude can be used on visualization tools, whether they are BI tools (PowerBI, Table), or Python DataViz libraries such as Plotly or Folium.
#
# Here we will display a map with Folium.

# %%
# The syntax of Folium is very simple, you start by creating a map centered on a point.
# You can change the default zoom level with the argument "zoom_start".

import folium

# We define a location as a list with 2 values : latitude and longitude.
point = [float(r[0]['lat']), float(r[0]['lon'])]

# We center the map on the location
m = folium.Map(location=point,zoom_start=7)

# We display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37f8dce0296c5d509c3d7fef4c999323 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37f8dce0296c5d509c3d7fef4c999323&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_37f8dce0296c5d509c3d7fef4c999323 = L.map(
#                 &quot;map_37f8dce0296c5d509c3d7fef4c999323&quot;,
#                 {
#                     center: [37.5111836, 15.094914],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b5910ddf9058d9c4f6edd89e0e224a26 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b5910ddf9058d9c4f6edd89e0e224a26.addTo(map_37f8dce0296c5d509c3d7fef4c999323);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Then you can add landmarks and put a clickable comment
m = folium.Map(location=point, )
folium.Marker(
    location=point,
    popup='a good restaurant'
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_214541162bc9da66b9a1ff8f89f02c9f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_214541162bc9da66b9a1ff8f89f02c9f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_214541162bc9da66b9a1ff8f89f02c9f = L.map(
#                 &quot;map_214541162bc9da66b9a1ff8f89f02c9f&quot;,
#                 {
#                     center: [37.5111836, 15.094914],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d6e85144a714774697f843e1f2162577 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d6e85144a714774697f843e1f2162577.addTo(map_214541162bc9da66b9a1ff8f89f02c9f);
#
#
#             var marker_bb23bfc1d86efd46bf936f3907647d83 = L.marker(
#                 [37.5111836, 15.094914],
#                 {
# }
#             ).addTo(map_214541162bc9da66b9a1ff8f89f02c9f);
#
#
#         var popup_7bf70d8085f0f8da5c7951544b9fa502 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b88f7a7902ed2fbbe5a9b44c967ca0b6 = $(`&lt;div id=&quot;html_b88f7a7902ed2fbbe5a9b44c967ca0b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;a good restaurant&lt;/div&gt;`)[0];
#                 popup_7bf70d8085f0f8da5c7951544b9fa502.setContent(html_b88f7a7902ed2fbbe5a9b44c967ca0b6);
#
#
#
#         marker_bb23bfc1d86efd46bf936f3907647d83.bindPopup(popup_7bf70d8085f0f8da5c7951544b9fa502)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Challenge
# Here is a DataFrame with restaurants in Catania, Sicily, and their respective addresses. Here is your mission:
# - Create a new column "coordinates", which will store the coordinates corresponding to each address (you can use the function you created previously).
# - Display a map with the 4 restaurant markers. Be careful, the restaurants are very close, remember to set the default zoom level so that it is clearly legible. You can center the map on the first restaurant. And display the name of the restaurant in the tooltip popup.

# %%
import pandas as pd
restaurants = pd.DataFrame([["Gelateria Zio Pietro dal 1964", "Via Porta di Ferro, 47, 95131 Catania CT"],
                            ["A Casa d'Amici","Via Fischetti, 14, 95131 Catania CT"],
                            ["La Bitta", "Via Acquicella Porto, 95121 Catania CT"],
                            ["Steak House", "Via Porta di Ferro, 8, 95100 Catania CT"]
                            ],
                           columns = ["name", "address"])

restaurants
# Out:
#                             name                                   address
# 0  Gelateria Zio Pietro dal 1964  Via Porta di Ferro, 47, 95131 Catania CT
# 1                 A Casa d'Amici       Via Fischetti, 14, 95131 Catania CT
# 2                       La Bitta    Via Acquicella Porto, 95121 Catania CT
# 3                    Steak House   Via Porta di Ferro, 8, 95100 Catania CT

# %%
restaurants['coord'] = [API_address(i) for i in restaurants.address]

# %%
restaurants
# Out:
#                             name                                   address  \
# 0  Gelateria Zio Pietro dal 1964  Via Porta di Ferro, 47, 95131 Catania CT
# 1                 A Casa d'Amici       Via Fischetti, 14, 95131 Catania CT
# 2                       La Bitta    Via Acquicella Porto, 95121 Catania CT
# 3                    Steak House   Via Porta di Ferro, 8, 95100 Catania CT
#
#                       coord
# 0  [37.5020931, 15.0931951]
# 1  [37.5061710, 15.0943223]
# 2  [37.4894403, 15.0794312]
# 3  [37.5026240, 15.0928853]

# %%
map = folium.Map(location=restaurants.coord[0], zoom_start=13)
for i, name in zip(range(restaurants.shape[0]), restaurants.name):   
    folium.Marker(
        location=restaurants.coord[i],
        popup=name
        ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b5a72a1c820b61a2d2f1fb3b6428efd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b5a72a1c820b61a2d2f1fb3b6428efd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b5a72a1c820b61a2d2f1fb3b6428efd = L.map(
#                 &quot;map_9b5a72a1c820b61a2d2f1fb3b6428efd&quot;,
#                 {
#                     center: [37.5020931, 15.0931951],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b7deb745941353d5b1183494c22c702 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b7deb745941353d5b1183494c22c702.addTo(map_9b5a72a1c820b61a2d2f1fb3b6428efd);
#
#
#             var marker_0e1d4781a27c26ffd613e3cd0174663c = L.marker(
#                 [37.5020931, 15.0931951],
#                 {
# }
#             ).addTo(map_9b5a72a1c820b61a2d2f1fb3b6428efd);
#
#
#         var popup_f8320b964343205e64f91ea409082be6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eed1dc40d6a4b08f5187949fb98a98c5 = $(`&lt;div id=&quot;html_eed1dc40d6a4b08f5187949fb98a98c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gelateria Zio Pietro dal 1964&lt;/div&gt;`)[0];
#                 popup_f8320b964343205e64f91ea409082be6.setContent(html_eed1dc40d6a4b08f5187949fb98a98c5);
#
#
#
#         marker_0e1d4781a27c26ffd613e3cd0174663c.bindPopup(popup_f8320b964343205e64f91ea409082be6)
#         ;
#
#
#
#
#             var marker_b5b9ffd7717b21386cc95284e1b44754 = L.marker(
#                 [37.506171, 15.0943223],
#                 {
# }
#             ).addTo(map_9b5a72a1c820b61a2d2f1fb3b6428efd);
#
#
#         var popup_b56ce616611a809efae3ab16e87657fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee3fe0ff5f19bb0f5a9278be872de25d = $(`&lt;div id=&quot;html_ee3fe0ff5f19bb0f5a9278be872de25d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A Casa d&#x27;Amici&lt;/div&gt;`)[0];
#                 popup_b56ce616611a809efae3ab16e87657fe.setContent(html_ee3fe0ff5f19bb0f5a9278be872de25d);
#
#
#
#         marker_b5b9ffd7717b21386cc95284e1b44754.bindPopup(popup_b56ce616611a809efae3ab16e87657fe)
#         ;
#
#
#
#
#             var marker_936d0e3e5416ac353bc44149df0e706b = L.marker(
#                 [37.4894403, 15.0794312],
#                 {
# }
#             ).addTo(map_9b5a72a1c820b61a2d2f1fb3b6428efd);
#
#
#         var popup_365e73d1aa4a24f939bf4a915dbd7fc8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_058103adee81ff9963eb90e497dbadf6 = $(`&lt;div id=&quot;html_058103adee81ff9963eb90e497dbadf6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;La Bitta&lt;/div&gt;`)[0];
#                 popup_365e73d1aa4a24f939bf4a915dbd7fc8.setContent(html_058103adee81ff9963eb90e497dbadf6);
#
#
#
#         marker_936d0e3e5416ac353bc44149df0e706b.bindPopup(popup_365e73d1aa4a24f939bf4a915dbd7fc8)
#         ;
#
#
#
#
#             var marker_1da6c4816d2c0341af9eff1aed2ae39f = L.marker(
#                 [37.502624, 15.0928853],
#                 {
# }
#             ).addTo(map_9b5a72a1c820b61a2d2f1fb3b6428efd);
#
#
#         var popup_bf30975c10423111e53efa6621dbb639 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ae467646a0cfe1bd6843e0967523505 = $(`&lt;div id=&quot;html_2ae467646a0cfe1bd6843e0967523505&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steak House&lt;/div&gt;`)[0];
#                 popup_bf30975c10423111e53efa6621dbb639.setContent(html_2ae467646a0cfe1bd6843e0967523505);
#
#
#
#         marker_1da6c4816d2c0341af9eff1aed2ae39f.bindPopup(popup_bf30975c10423111e53efa6621dbb639)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
